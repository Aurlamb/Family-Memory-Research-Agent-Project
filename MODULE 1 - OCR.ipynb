# %% [markdown]
# # Project Memory

# %% [markdown]
# ## Environment elements

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from pathlib import Path

# Load path from the environment variable
env_ih1 = os.getenv("ENV_IH1")

dotenv_path = Path(env_ih1)
load_dotenv(dotenv_path=dotenv_path)
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
PINECONE_API_KEY= os.getenv('PINECONE_KEY')
SERPAPI_API_KEY = os.getenv('SERPAPI_API_KEY')
STEAMSHIP_API_KEY = os.getenv('STEAMSHIP_API_KEY')
LANGSMITH_API_KEY = os.getenv('LANGSMITH_API_KEY')
HUGGINGFACEHUB_API_TOKEN = os.getenv('HUGGINGFACEHUB_API_TOKEN')
GEMINI_KEY = os.getenv('GEMINI_KEY')

os.environ['PATH'] += os.pathsep + '/usr/bin'

# %% [markdown]
# ## Libraries

# %%
# # This notebook requires Tesseract for OCR
# %pip install --upgrade openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: openai in c:\users\aurel\appdata\roaming\python\python312\site-packages (1.60.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\programdata\anaconda3\lib\site-packages (from openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\programdata\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\programdata\anaconda3\lib\site-packages (from openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\aurel\appdata\roaming\python\python312\site-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\aurel\appdata\roaming\python\python312\site-packages (from openai) (2.10.5)
# Requirement already satisfied: sniffio in c:\programdata\anaconda3\lib\site-packages (from openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in c:\users\aurel\appdata\roaming\python\python312\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\aurel\appdata\roaming\python\python312\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\aurel\appdata\roaming\python\python312\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\aurel\appdata\roaming\python\python312\site-packages (from httpx<1,>=0.23.0->openai) (2024.12.14)
# Requirement already satisfied: httpcore==1.* in c:\programdata\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\programdata\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\aurel\appdata\roaming\python\python312\site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: colorama in c:\users\aurel\appdata\roaming\python\python312\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Gemini OCR

# %%
import os
import pandas as pd
import json
from PIL import Image
import google.generativeai as genai
from datetime import datetime
import cv2
import re

# Replace with your actual API key
genai.configure(api_key=GEMINI_KEY)
model = genai.GenerativeModel("gemini-1.5-flash-latest")

def get_image_paths_from_folder(folder_path, extensions=('.jpg', '.jpeg', '.png')):
    return [
        os.path.join(folder_path, file)
        for file in os.listdir(folder_path)
        if file.lower().endswith(extensions)
    ]

def preprocess_image(image_path):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    _, thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY)
    return thresh

def extract_page_region(image_path, location='top'):
    image = Image.open(image_path)
    width, height = image.size
    if location == 'top':
        return image.crop((0, 0, width, int(height * 0.5)))  # Top 10%
    elif location == 'bottom':
        return image.crop((0, int(height * 0.5), width, height))  # Bottom 10%
    return None

def correct_page_number(prev_page, current_page):
    if prev_page is None or current_page is None:
        return current_page
    
    str_current = str(current_page)
    str_prev = str(prev_page)
    
    if ('8' in str_current or '0' in str_current) and abs(prev_page - current_page) > 2:
        candidates = [
            int(str_current.replace('8', '0')) if '8' in str_current else current_page,
            int(str_current.replace('0', '8')) if '0' in str_current else current_page
        ]
        candidates.append(current_page)  # Keep original as a fallback
        candidates = [c for c in candidates if abs(prev_page - c) <= 2]  # Filter valid candidates
        if candidates:
            return min(candidates, key=lambda x: abs(prev_page - x))  # Choose closest
    return current_page

def extract_text_and_page_number(image_path, page_location='top'):
    try:
        image = Image.open(image_path)
        prompt_full = f"Extract the full text from the provided image."
        generation_config = genai.types.GenerationConfig(
            temperature=0.1,
            max_output_tokens=1024
        )
        response_full = model.generate_content([prompt_full, image], generation_config=generation_config)
        full_text = response_full.text
        
        page_number = None
        if page_location in ['top', 'bottom']:
            region = extract_page_region(image_path, location=page_location)
            if region:
                prompt_page = f"Identify the page number from this image region."
                response_page = model.generate_content([prompt_page, region], generation_config=generation_config)
                page_text = response_page.text
                page_number_match = re.search(r'\b\d+\b', page_text)
                page_number = int(page_number_match.group()) if page_number_match else None

        return full_text, page_number
    except Exception as e:
        print(f"Error processing {image_path}: {e}")
        return "", None

def process_images(image_paths, page_location='top'):
    pages = []
    prev_page_number = None
    
    for path in image_paths:
        text, page_number = extract_text_and_page_number(path, page_location=page_location)
        corrected_page_number = correct_page_number(prev_page_number, page_number)
        prev_page_number = corrected_page_number if corrected_page_number is not None else prev_page_number

        print(f"Extracted Text for {path}: {text[:100]}...")
        print(f"Page Number (corrected): {corrected_page_number}")

        text = str(text).strip() if text else "No text extracted"
        metadata = {
            "Image Path": path,
            "Extracted Text": text,
            "Page Number": corrected_page_number
        }
        pages.append(metadata)
    return pages

def save_to_json(metadata_list, output_dir, name, author, type):
    os.makedirs(output_dir, exist_ok=True)
    file_name = f"{name}_{author}.json"
    output_path = os.path.join(output_dir, file_name)
    document_metadata = {
        "Author": author,
        "Name": name,
        "Date": datetime.now().strftime("%Y-%m-%d %H:%M:%S"),
        "Pages": metadata_list,
        "Type": type
    }
    with open(output_path, 'w', encoding='utf-8') as json_file:
        json.dump(document_metadata, json_file, indent=4, ensure_ascii=False)
    print(f"JSON saved to: {output_path}")

def main(
    image_folder,
    output_dir,
    name,
    author,
    page_location='top'
):
    image_paths = get_image_paths_from_folder(image_folder)
    if not image_paths:
        print(f"No images found in folder: {image_folder}")
        return

    metadata_list = process_images(image_paths, page_location)
    save_to_json(metadata_list, output_dir, name, author, type=config['type'])

if __name__ == "__main__":
    config = {
        'image_folder': r'data\Photos\Livre Mémoires 1-50',
        'output_dir': r'C:\Users\aurel\OneDrive\Documents\Python\IronHack\Project\data\Family safe',
        'name': "Pour la mémoire familiale 1-50",
        'author': "Jean Lambert",
        'page_location': 'top',
        'type': 'scan'
    }

    main(
        image_folder=config['image_folder'],
        output_dir=config['output_dir'],
        name=config['name'],
        author=config['author'],
        page_location=config['page_location']
    )
# Out:
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142502.jpg: POUR LA MÉMOIRE
# FAMILIALE
#
# FAMILLE HISTOIRE
# SOUVENIRS & COMMENTAIRES
#
# VOLUME 1
#
# Jean-Georges Lambert...
# Page Number (corrected): 1
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142520.jpg: J'ai entrepris ce travail pour mes fils qui tiennent à parts égales, tant de place dans ma vie.  Je ...
# Page Number (corrected): None
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142527.jpg: VOLUME 1
#
# Page
# 6- Préambule.
#
# TABLE DES MATIERES DES VOLUMES 1 & 2
# -TONE 1-MA FAMILLE PATERNELLE -
#
# ...
# Page Number (corrected): None
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142533.jpg: -Les sentiments de Bonaparte, puis de Napoléon, envers les juifs -Les décrets de 1808 -
# Vers l'égali...
# Page Number (corrected): None
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142539.jpg: sont pas seuls visés par cette campagne Mon père et l'antisémitisme avant l'affaire
# Drevfus L'Affair...
# Page Number (corrected): None
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142545.jpg: PREAMBULLE
#
# La mort de ma mère m'a profondément touché.
# Elle avait soixante dix sept ans, et moi j'a...
# Page Number (corrected): None
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142552.jpg: vieillots, et quand je les entendais d'une oreille
# distraite il m'en restait bien peu en mémoire. Il...
# Page Number (corrected): 7
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142558.jpg: ans, Francis en avait dix, Jean-Paul huit et Gérard cinq.
# Comme elle ne vivait pas avec nous vous ne...
# Page Number (corrected): 8
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142604.jpg: Maintenant avec la retraite, même en m'occupant, j'aurai bien un peu de temps libre pour rassembler ...
# Page Number (corrected): 9
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142622.jpg: POUR LA MEMOIRE FAMILIALE
# FAMILLE HISTOIRE SOUVENIRS & COMMENTAIRES
# +++++
# TOME I
# ***
# MA FAMILLE PATE...
# Page Number (corrected): 10
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142629.jpg: PREAMBULE DU TOME I
#
# 11
#
# Il y a maintenant près de six ans que j'ai écrit le préambule que vous avez...
# Page Number (corrected): 11
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142640.jpg: 12
#
# des juifs en Alsace-Lorraine aux XVII et XVIII siècle. Mais je lisais d'autres livres traitants ...
# Page Number (corrected): 12
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142646.jpg: 13
#
# L'information que j'amassais ainsi ne cessait de s'apporter chaque jour de nouveaux
# problèmes ca...
# Page Number (corrected): 13
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142652.jpg: 14
#
# d'incompréhension quand on veut rapporter l'histoire de ceux qui nous ont précédés. L'obstacle d...
# Page Number (corrected): 14
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142658.jpg: A l'époque de la Révolution on pourrait multiplier les exemples des communautés pour lesquelles l'hi...
# Page Number (corrected): 15
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142716.jpg: On parle souvent depuis quelques années du besoin de retrouver ses racines. C'est un sentiment que j...
# Page Number (corrected): 16
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142722.jpg: Cela... Pour toute ces raisons, et malgré ses efforts de relecture, je crains que le résultat ne soi...
# Page Number (corrected): 17
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142728.jpg: 18
#
# PREMIÈRE PARTIE
#
# POUR FAIRE LE POINT
# AU TEMPS DE MA JEUNESSE...
# Page Number (corrected): 18
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250127_142735.jpg: Chapitre I
# OBJET DE CETTE PREMIERE PARTIE
#
# 19
#
# En cette fin de XXe siècle, on constate à la fois une...
# Page Number (corrected): 19
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132002.jpg: Chapitre II
# UN CLIMAT PASSIONNEL
#
# 20
#
# -Le génocide nazi.
#
# Dans l'histoire des hommes il y a toujours...
# Page Number (corrected): 20
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132010.jpg: 21
#
# victime, alors que le raciste anti-noir, dont la haine n'est pas moins irrationnelle, a pour obj...
# Page Number (corrected): 21
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132017.jpg: 22
#
# Ensuite on a vu la progression des commentaires qui tendent à banaliser les crimes nazis.
# Cela c...
# Page Number (corrected): 22
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132022.jpg: 23
#
# agressivité, et dans l'Empire Ottoman les juifs accèdent à des postes officiels importants. Le v...
# Page Number (corrected): 23
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132030.jpg: 24
#
# Quand j'étais jeune, les livres consacrés aux juifs étaient rares, et on n'en parlait pas.
# Quant...
# Page Number (corrected): 24
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132054.jpg: Chapitre III
#
# LES JUIFS EN FRANCE ENTRE LES DEUX GUERRE
#
# 25
#
# Comme je vais parler de moi, je commenc...
# Page Number (corrected): 25
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132111.jpg: l'instruction religieuse des chrétiens, on se parlait des juifs, des lévites. Mais, comme l'histoire...
# Page Number (corrected): 26
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132143.jpg: ne m'a jamais dit que c'était une mauvaise fréquentation, au contraire il l'aimait beaucoup. Il n'a
# ...
# Page Number (corrected): 27
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132150.jpg: reconnaître qu'au niveau des groupes, les français sont plutôt xénophobes, et que c'est une attitude...
# Page Number (corrected): 28
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132156.jpg: vivre au milieu de la société française. "Vidal et les siens", que j'ai déjà cité, entre dans cette
# ...
# Page Number (corrected): 29
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132204.jpg: exploités comme travailleurs clandestins. Elle écrit aussi que ces mêmes milieux les considéraient p...
# Page Number (corrected): 30
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132211.jpg: souvenir qu'en France il ai eu le moindre souci à ce sujet. Lévy-Strauss, à qui un journaliste deman...
# Page Number (corrected): 31
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132221.jpg: s'est déroulée avec les autres, sans problème particulier pour nous, du moins à ce titre. Notre souc...
# Page Number (corrected): 32
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132228.jpg: 33
#
# commissaire aux affaires juives! Heureusement pour elle, elle en sort. (Gérard Oury - Histoires
# ...
# Page Number (corrected): 33
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132248.jpg: savent, et, je le suppose, d'autres au tribunal doivent aussi le savoir. Et chacun agit comme si la
# ...
# Page Number (corrected): 34
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132255.jpg: Très proche encore, votre grand-père maternel, cet homme adorable que vous avez connu.
# Votre mère m'...
# Page Number (corrected): 35
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132302.jpg: 36
#
# dans la "milice". Ils étaient probablement gendarmes ou policiers avant la défaite, et tout ce q...
# Page Number (corrected): 36
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132308.jpg: auraient pu être des antisémites affreux capables des pires exactions, capables seulement de dénonci...
# Page Number (corrected): 37
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132316.jpg: agissait au mieux des intérêts de la France. Aucun homme politique n'aurait pu avoir cette autorité ...
# Page Number (corrected): 38
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132323.jpg: Chapitre IV
#
# LE PROTESTANTISME - LE PATRIOTISME
#
# 39
#
# J'ai mentionné qu'enfant j'allais à l'Ecole du ...
# Page Number (corrected): 39
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132330.jpg: Mais il y avait aussi des réalités beaucoup plus proches et tangibles pour l'enfant que j'étais. Ain...
# Page Number (corrected): 40
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132340.jpg: 41
#
# DEUXIÈME PARTIE
#
# REFLEXION SUR L’HISTOIRE ET LES JUIFS...
# Page Number (corrected): 41
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132347.jpg: Chapitre V
# DE L'ORIGINE DE LA DIASPORA A L'EMPIRE ROMAIN
#
# 42
#
# -Pourquoi chercher si loin.
#
# Je n'avai...
# Page Number (corrected): 42
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132353.jpg: Ensuite la vie sur la Terre Promise est marquée au cours des siècles par des guerres avec d'autres p...
# Page Number (corrected): 43
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132401.jpg: Plus tard beaucoup de juifs se sont répandus de tous côtés pour fuir la guerre, les
# déportations, ma...
# Page Number (corrected): 44
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132408.jpg: sont incompatibles avec leur foi. Ils occupent souvent des situations de premier plan dans tous les
# ...
# Page Number (corrected): 45
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132557.jpg: -Les juifs en Gaule et sur les bords du Rhin.
# L'implantation des juifs sur les bords du Rhin est ant...
# Page Number (corrected): 46
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132604.jpg: 47
# collectivement coupable de la mort de Jésus; leur dispersion à travers le monde est le châtiment ...
# Page Number (corrected): 47
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132610.jpg: Gérald Messadié, dans le même ouvrage, discute la valeur des évangiles canonisés plus de quatre sièc...
# Page Number (corrected): 48
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132615.jpg: 49
#
# Et peu importe si la diaspora arrangée pour être présentée comme une malédiction n'a rien à
# voir...
# Page Number (corrected): 49
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132621.jpg: Chapitre VI
# DE L'EMPIRE ROMAIN A L'AN 1000
#
# 50
#
# -De l'arrivée des barbares au VII<sup>e</sup> siècle...
# Page Number (corrected): 50
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132628.jpg: -L'Empire Carolindien du VIII au Xe siècles
#
# Avec Charlemagne, l'ordre est rétabli en Europe Occiden...
# Page Number (corrected): 51
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132634.jpg: -Le judaïsme et l'activité intellectuelle des juifs
#
# La destruction du temple en 70 ap.JC, puis l'in...
# Page Number (corrected): 52
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132640.jpg: Chapitre VII
# DU XI<sup>e</sup> AU XV<sup>e</sup> SIÈCLE
#
# 53
#
# -La situation des Juifs au début du deu...
# Page Number (corrected): 53
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132646.jpg: 54
#
# juifs qui détenaient d'énormes fortunes devinrent tout naturellement, comme leurs contemporains ...
# Page Number (corrected): 54
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132652.jpg: 55
#
# princes et l'asservissement du peuple. Cette suprématie est maintenant menacée. Jusqu'à présent ...
# Page Number (corrected): 55
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132659.jpg: 56
#
# -L'exil.
# laquelle les pieux chevaliers convaincus de leur mission sont débordés par une populace...
# Page Number (corrected): 56
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132707.jpg: 57
#
# riches orthodoxes de l'Empire Byzantin. Et l'on estime qu'au court de ces exactions il mourut pl...
# Page Number (corrected): 57
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132716.jpg: Lors de l'expulsion du Royaume de France en 1322, et ensuite l'expulsion définitive en
# 1394, beaucou...
# Page Number (corrected): 58
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132724.jpg: Chapitre VIII
# DU XVI° SIECLE A LA REVOLUTION
#
# 59
#
# -La situation en France du début du XVI° siècle.
# L...
# Page Number (corrected): 59
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132731.jpg: 68
#
# Le premier pays à leur ouvrir ses frontières est la Hollande, pays protestant qui vient de prend...
# Page Number (corrected): 60
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132739.jpg: 61
#
# situations d'une certaine importance. Parmi eux on voit apparaître, en Prusse comme dans d'autre...
# Page Number (corrected): 61
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132746.jpg: 62
#
# La Russie et les pays qui en dépendent ne sont pas affectés par cette évolution. Il faudra
# atten...
# Page Number (corrected): 62
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132752.jpg: 63
#
# Ils sont répartis en communautés ayant chacune leurs particularités. En effet il n'y a pas
# de ju...
# Page Number (corrected): 63
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132801.jpg: Ces séfarades qui parlent français vivent tout à fait intégrés à la population, qui les accepte et l...
# Page Number (corrected): 64
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132808.jpg: -Les contadins et les avignonais.
# Les "juifs du pape" sont installés en Avignon et dans le Comtat Ve...
# Page Number (corrected): 65
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132815.jpg: -L'Histoire avec un grand "H" et la petite histoire de la famille.
# J'arrive maintenant aux juifs de ...
# Page Number (corrected): 66
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132825.jpg: 67
# confirmer les privilèges des juifs. En 1657, c'est Louis XIV qui tient à manifester sa bienveilla...
# Page Number (corrected): 67
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132831.jpg: 68
#
# Quelle est alors le niveau de vie des juifs en Lorraine? Au sujet de Metz où l'ancienneté
# de la ...
# Page Number (corrected): 68
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132839.jpg: Cet appauvrissement est dû pour une part à l'augmentation constante des taxes de toutes sortes impos...
# Page Number (corrected): 69
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132846.jpg: Leurs activités sont les mêmes qu'en Lorraine, avec une part d'usure en milieu paysan beaucoup plus ...
# Page Number (corrected): 70
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132853.jpg: 71
#
# rapports avec la population locale sont d'autant plus difficiles que le plus grand nombre, surto...
# Page Number (corrected): 71
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132858.jpg: 72
#
# prioritaire pour le pouvoir.
# dans un très petit nombre de régions la population ne s'y intéresse...
# Page Number (corrected): 72
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132906.jpg: 73
#
# prévoyant probablement cette réaction, et sans attendre les prises de position des parlements, a...
# Page Number (corrected): 73
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132912.jpg: Chapitre IX
# LA REVOLUTION ET LE DIRECTOIRE
#
# 74
#
# Ma rencontre avec cette période de l'histoire.
# Essay...
# Page Number (corrected): 74
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132917.jpg: 75
#
# Et dans cet assemblage où l'on trouvait des modèles de société et des organisations du
# pouvoir s...
# Page Number (corrected): 75
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132924.jpg: 76
#
# qu'on leur accorde de titre de citoyens, et encore avec des restrictions. Le plus souvent, ceux ...
# Page Number (corrected): 76
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132931.jpg: -il faut changer cette situation en les régénérant.
# -la société chrétienne doit réparer ses torts.
# -...
# Page Number (corrected): 77
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132936.jpg: -Les étapes de la Révolution:
# Les Etats généraux et la Constituante-(1789-30 septembre 1791),
# Les pr...
# Page Number (corrected): 78
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132942.jpg: Dans le moment de régénération où les abus sont détruits, où les préjugés disparaissent, et quand l'...
# Page Number (corrected): 79
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132948.jpg: ---
# 88
#
# Assemblée législative, la Convention et la 1<sup>re</sup> République (1<sup>er</sup> octobre...
# Page Number (corrected): 88
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_132954.jpg: que.
# 31
# respectes, et que cela etait bien connu de tous ceux avec oui ils traitaient.
# maiore le mal ...
# Page Number (corrected): 31
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_133001.jpg: 82
#
# civils aux juifs est l'aboutissement d'un long processus entamé et en partie mené à bien par l'a...
# Page Number (corrected): 82
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_133008.jpg: Chapitre X
# DU CONSULAT A LA FIN DU SECOND EMPIRE
#
# 83
#
# Les sentiments de Bonaparte, puis Napoléon, en...
# Page Number (corrected): 83
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_133016.jpg: -Les décrets de 1808.
# 84
# Avant ces décrets on peut faire une première remarque. Pour que la paix fût...
# Page Number (corrected): 84
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_133023.jpg: 85
#
# Napoléon voulait aller plus loin. Les décisions pour avoir tout leur poids devaient être entérin...
# Page Number (corrected): 85
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_133028.jpg: Le décret sur l'usure mettait en place un ensemble complexe de mesures, et avait pour conséquence de...
# Page Number (corrected): 86
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_133037.jpg: 87
#
# noins que d'appliquer la ligne de conduite générale de sa politique.
# encadrement un prestige et ...
# Page Number (corrected): 87
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_133042.jpg: La Restauration peut mettre à son actif d'avoir redonné aux juifs la dignité de citoyens.
# Mais, pers...
# Page Number (corrected): 88
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_133048.jpg: L'exode de nombreux juifs d'Alsace rendit alors tout nouveau recours impossible, et ait un point fin...
# Page Number (corrected): 89
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_133055.jpg: Chapitre XI
#
# L'EVOLUTION DES JUIFS D'ALSACE LORRAINE AU COURS DU XIX SIECLE
#
# 98
#
# recherche difficile...
# Page Number (corrected): 90
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_133101.jpg: 91
#
# Alors je ne suis procure cet ouvrage dans la collection du livre de poche, dont la couverture pr...
# Page Number (corrected): 91
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_133110.jpg: 92
#
# Dopulation juive alsacienne en 1825, était tombé à 13% en 1857,
# les couches ovennestus, de la bo...
# Page Number (corrected): 92
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_133117.jpg: Un autre aspect de la volonté d'oubli. Au fur et à mesure que l'on avance dans le XIX<sup>e</sup> si...
# Page Number (corrected): 93
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_133125.jpg: 94
#
# Cet évolution du judaisme dans les esprits s'accompagne d'une évolution dans les formes ou
# en Eu...
# Page Number (corrected): 94
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_133131.jpg: 95
#
# autrement que de reconnaître leurs brillantes performances
# du monde entier. Les gouvernements ne...
# Page Number (corrected): 95
# Extracted Text for data\Photos\Livre Mémoires 1-50\20250128_133143.jpg: En 1871, sauf rares exceptions, l'Administration, armée, diplomatie, magistrature, préfets, universi...
# Page Number (corrected): 96
# JSON saved to: C:\Users\aurel\OneDrive\Documents\Python\IronHack\Project\data\Family safe\Pour la mémoire familiale 1-50_Jean Lambert.json
