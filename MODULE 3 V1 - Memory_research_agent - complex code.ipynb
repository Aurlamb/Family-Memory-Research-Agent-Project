# %% [markdown]
# # Agent Memory Project

# %% [markdown]
# ## Load env

# %%
import os
import openai

from openai import OpenAI
from dotenv import load_dotenv
from pathlib import Path

# Load path from the environment variable
env_ih1 = os.getenv("ENV_IH1")

dotenv_path = Path(env_ih1)
load_dotenv(dotenv_path=dotenv_path)
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
PINECONE_API_KEY= os.getenv('PINECONE_KEY')
SERPAPI_API_KEY = os.getenv('SERPAPI_API_KEY')
STEAMSHIP_API_KEY = os.getenv('STEAMSHIP_API_KEY')
LANGSMITH_API_KEY = os.getenv('LANGSMITH_API_KEY')
HUGGINGFACEHUB_API_TOKEN = os.getenv('HUGGINGFACEHUB_API_TOKEN')
GEMINI_KEY = os.getenv('GEMINI_KEY')

os.environ['PATH'] += os.pathsep + '/usr/bin'

# %%
from langsmith import wrappers, traceable

LANGSMITH_API_KEY= LANGSMITH_API_KEY
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"]="https://api.smith.langchain.com"
os.environ["LANGCHAIN_PROJECT"]="memory-project"

# %% [markdown]
# ## Load Pinecone DB

# %%
import time
from pinecone import Pinecone

# configure client
pc = Pinecone(api_key=PINECONE_API_KEY)

# Connect to the existing index
index_name = "memory-project4"  # Replace with your existing index name
# connect to index
index = pc.Index(index_name)
time.sleep(1)
# view index stats
index.describe_index_stats()
# Out:
# {'dimension': 1536,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 170}},
#  'total_vector_count': 170}

# %%
from langchain.vectorstores import Pinecone as LangchainPinecone
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.schema import Document

## Create encoder
from semantic_router.encoders import OpenAIEncoder

encoder = OpenAIEncoder(
    name="text-embedding-3-small",
    openai_api_key=OPENAI_API_KEY 
)

## Creating retriever

# Initialize OpenAI Embeddings with text-embedding-3-small
embeddings = OpenAIEmbeddings(model="text-embedding-3-small", openai_api_key=OPENAI_API_KEY)

# Initialize LangChain Pinecone retriever
vectorstore = LangchainPinecone(index, embeddings, text_key="text")
retriever = vectorstore.as_retriever()
# Out:
# C:\Users\aurel\AppData\Local\Temp\ipykernel_23468\1506975490.py:16: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-openai package and should be used instead. To use it run `pip install -U :class:`~langchain-openai` and import as `from :class:`~langchain_openai import OpenAIEmbeddings``.
#   embeddings = OpenAIEmbeddings(model="text-embedding-3-small", openai_api_key=OPENAI_API_KEY)
# C:\Users\aurel\AppData\Local\Temp\ipykernel_23468\1506975490.py:19: LangChainDeprecationWarning: The class `Pinecone` was deprecated in LangChain 0.0.18 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-pinecone package and should be used instead. To use it run `pip install -U :class:`~langchain-pinecone` and import as `from :class:`~langchain_pinecone import Pinecone``.
#   vectorstore = LangchainPinecone(index, embeddings, text_key="text")

# %%
# Test retrieval
query = "Who is Jean Lambert?"
results = retriever.get_relevant_documents(query)

# Print results
for doc in results:
    print(f"Content: {doc.page_content}")
    print(f"Metadata: {doc.metadata}")
    print("-" * 50)
# Out:
# C:\Users\aurel\AppData\Local\Temp\ipykernel_23468\3093734283.py:3: LangChainDeprecationWarning: The method `BaseRetriever.get_relevant_documents` was deprecated in langchain-core 0.1.46 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   results = retriever.get_relevant_documents(query)
# Content: POUR LA MÉMOIRE
# FAMILIALE
#
# FAMILLE HISTOIRE
# SOUVENIRS & COMMENTAIRES
#
# VOLUME 1
#
# Jean-Georges Lambert
# Avril 1993
# Metadata: {'Author': 'Jean Lambert', 'Chunk_ID': 'Pour la mémoire familiale 1-50_Chunk1', 'Doc name': 'Pour la mémoire familiale 1-50', 'Page_number': 1.0, 'Total_Chunks': 1.0}
# --------------------------------------------------
# Content: de Maman Michel, et il est mort à Reims le 4 mars 1893 âgé de soixante quatre ans.
#
# Son influence sur la famille est de plus courte durée que celle de Maman Michel, mais c'est aussi une forte personnalité qui a joué un rôle important dans le déroulement de la vie familiale.
#
# L'histoire de Jacques Dreyfus commence à l'époque où il exerçait la profession de colporteur. C'est le terme qu'employait mon père, mais je pense qu'il n'est pas exact, en raison de l'importance de son commerce. Je dirais plutôt négociant en tissus, en précisant qu'il l'exerçait en ambulant. Il avait pour cela une voiture à deux chevaux assez spacieuse et confortable. Il était propriétaire de l'ensemble, ce qui paraît assez rare dans cette profession à cette époque. Il faisait des tournées d'environ six mois et son itinéraire comportait beaucoup de petits bourgs qui n'étaient pas desservis par les diligences. C'est à dire qu'il voyageait en zigzag autour de la grande route. Il ne faisait pas les marchés, mais approvisionnait les revendeurs.
# Metadata: {'Author': 'John Doe', 'Chunk_ID': 'Pdf img_Chunk2', 'Doc name': 'Pdf img', 'Page_number': 118.0, 'Total_Chunks': 2.0}
# --------------------------------------------------
# Content: 68
#
# Quelle est alors le niveau de vie des juifs en Lorraine? Au sujet de Metz où l'ancienneté
# de la présence française permet d'avoir plus d'informations, Gilbert Cahen écrit dans la préface d'un
# recueil de contrats de mariage juifs: "Si l'on commence aujourd'hui à connaître le rôle déterminant joué par
# les notables dans l'histoire des communautés juives et même de la cité, de nombreux aspects de leur vie
# quotidienne et, à fortiori, celle des humbles reste largement ignorée; entre autres le logement et les
# ressources des jeunes ménages, la formation aux affaires ou la poursuite de l'instruction des jeunes
# cela j'ai encore bien du mal à répondre.
# naris....". La difficulté est encore plus grande en dehors des Evêchés. J'ai beaucoup cherché, et malgré
# mes premières recherches s'ont conduit à des textes qui montraient une pauvreté extrême et
# généralisée, dont voici un exemple. Un juif lorrain évolué, Isaac Berr Bing, dépeint la situation en 1789 en
# ces termes :"ces figures blêmes, ces fripiers ambulants...., chargés de quenilles sur lesquelles ils fondent
# journellement l'espoir d'un pain accompagné de tant d'insultes et de mépris que l'horreur de la famine seule
# peut déterminer à rechercher.... Elles retournent s'enterrer le soir dans ces demeures sombres, vraies images
# du tombeau, qu'elles partagent avec leurs familles".
# Plus tard j'ai eu connaissance d'un recensement de 2021 contrats de mariages juifs passés
# en Moselle, le plus grand nombre ayant été faits à Metz. Il est intéressant de savoir que les juifs ne
# tenaient pas d'Etat civil, mais par contre qu'ils passaient très souvent des contrats de mariage, peut être
# en raison de cet absence d'état civil. Ces contrats appelés "ketouba" étaient passés entre les parents des
# époux et rédigés en hébreu. A partir d'une certaine époque, beaucoup de juifs éprouvèrent le besoin de faire
# enregistrer ces actes devant des notaires royaux après traduction. Dans ce recensement j'ai regardé les
# professions exercées, et j'ai relevé: en très petit nombre, docteur en médecine, entrepreneur de forge,
# rabbin, chantre à la synagogue, syndic de communauté, puis en plus grand nombre, banquier avec les variantes
# marchand banquier et banquier négociant, et surtout des commerçants sous les appellations variées de
# marchand, négociant, marchand magasinier, marchand drapier, marchand boucher, marchand de bestiaux, marchand
# de chevaux, et aussi boucher, bijoutier, fripier. Cette énumération montrant, il me semble, l'existence de
# situations sociales qui n'évoquent pas la misère. D'ailleurs si l'on fait des contrats de mariage, c'est
# pour y sentionner des biens, or il semble que l'usage de ces contrats était assez généralisé, et que seuls
# les plus pauvres n'y avaient par recours.
# Et puis j'ai eu connaissance de fortunes considérables acquises par ceux qui concluaient
# les gros marchés avec l'armée, ou ceux avec lesquels le duc Léopold s'est lancé dans des opérations
# financières importantes. Ils constituent une minorité opulente qui possède des inmeubles dans les grandes
# villes malgré les interdictions, accumule bijoux et oeuvres d'art, et vit dans un faste extrême. On voit
# chez eux le luxe de la table et des costumes, et aussi des fêtes brillantes avec des quantités d'invités. Et
# l'on voit même un juif de Strasbourg, Cerf Berr, acheter en Lorraine le fief de Tombelaine,
# Metadata: {'Author': 'Jean Lambert', 'Chunk_ID': 'Pour la mémoire familiale 1-50_Chunk1', 'Doc name': 'Pour la mémoire familiale 1-50', 'Page_number': 68.0, 'Total_Chunks': 2.0}
# --------------------------------------------------
# Content: C'est le dernier, Isaac, dit Hovel, le plus souvent appelé Louis qui est notre ancêtre direct à la génération suivante. Il est né en 1766 à Froeningen, et s'est marié avec Rachel (ou Reiche ou Rosalie ou Thérèse) Gugenheim, née également à Froeningen en 1772, et décédée dans le même village en 1843, à 81 ans.
#
# Du ménage Louis et Rachel, je connais six enfants: Charlotte ex Judele, Jacques ex Jacob, marchand de bestiaux, Alexandre ex Samuel, marchand de bestiaux, Lehmann ou Clément, Marx, marchand de bétail, et Julie ex Sara, tous nés à Froeningen entre 1795 et 1802.
#
# Parmi eux, notre ancêtre direct est Lehmann, sur son prénom je note qu'en 1808 il devient Clément, mais que seul le prénom de Lehmann continuera à être employé par la suite. Il est né en 1800 à Froeningen, et décédé au même lieu en 1843. En 1827 il a épousé Athelle (ou Adèle, ou Esther) Bloch, née à Soultz, village proche de Froeningen, en 1803, que j'ai déjà mentionnée.
#
# Lehmann et Adèle ont eu neuf enfants dont j'ai connaissance, tous nés à Froeningen, et qui sont: Gabriel né le 3/2/1828 et décédé six semaines plus tard, Jacques né le 9 janvier 1829, Sophie née le 4/10/1830, Louise née le 27/7/1832, Sara ou Charlotte née le 12/8/1834, Marx ou Michel né le 26/4/1836, Cerf ou Hirtz né le 14/11/1838, Judith née en 1840, et Samuel né le 22/4/1843.
#
# J'ai eu beaucoup de mal avec leur instabilité de prénoms. Bien que mon père les ai connu à la fin du XIXe siècle, il parle de certains sous un prénom, et retrouvant d'autres noms sur des papiers divers, j'ai pensé par moment qu'il devaient être plus nombreux. Mais quand, par exemple, il a manqué des noms sur des papiers de succession, il y avait évidemment des impossibilités. Alors qui était qui?...je n'ai pas trouvé tout de suite.
#
# Parmi eux notre ascendant direct est Jacques Dreyfus, qui est en fait l'aîné de la famille. Je vais parler de lui et de ses frères et soeurs plus en détail, car c'est une génération que mon père a connue.
#
# -Jacques Dreyfus.
#
# Jacques Dreyfus avait quarante huit ans à la naissance de son père, qui a bien connu son grand-père.
#
# Jacques Dreyfus est né à Froeningen le 9 janvier 1829. C'est au moins la troisième génération venue au monde dans ce village. Il s'est marié le 4 juillet 1860 à Reims avec Catherine Lévy, fille de Maman Michel, et il est mort à Reims le 4 mars 1893 âgé de soixante quatre ans.
#
# Son influence sur la famille est de plus courte durée que celle de Maman Michel, mais c'est aussi une forte personnalité qui a joué un rôle important dans le déroulement de la vie familiale.
#
# L'histoire de Jacques Dreyfus commence à l'époque où il exerçait la profession de colporteur. C'est le terme qu'employait mon père, mais je pense qu'il n'est pas exact, en raison de l'importance de son commerce. Je dirais plutôt négociant en tissus, en précisant qu'il l'exerçait en ambulant. Il avait pour cela une voiture à deux chevaux assez spacieuse et
# Metadata: {'Author': 'John Doe', 'Chunk_ID': 'Pdf img_Chunk1', 'Doc name': 'Pdf img', 'Page_number': 118.0, 'Total_Chunks': 2.0}
# --------------------------------------------------

# %% [markdown]
# ## Create Graph Agent

# %%
from typing import TypedDict, Annotated, List, Union
from langchain_core.agents import AgentAction, AgentFinish
from langchain_core.messages import BaseMessage
import operator


class AgentState(TypedDict):
    input: str
    chat_history: list[BaseMessage]
    intermediate_steps: Annotated[list[tuple[AgentAction, str]], operator.add]

# %% [markdown]
# ## Create custom tools

# %%
from langchain_core.tools import tool
import re


def format_rag_contexts(matches: list):
    """Formats retrieved document matches into a readable context string."""
    contexts = []
    for x in matches:
        metadata = x.get("metadata", {})  # Safely get metadata
        text = (
            f"Doc name: {metadata.get('Doc name', 'N/A')}\n"
            f"Author: {metadata.get('Author', 'N/A')}\n"
            f"Chunk_ID: {metadata.get('Chunk_ID', 'N/A')}\n"
            f"Content: {metadata.get('text', 'No content available')}"  # Fixed page content reference
        )
        contexts.append(text)

    return "\n---\n".join(contexts)

""""
@tool("simple_search")  # Fixed invalid tool name
"""
# def simple_search(query: str):
#     """Finds related information using a natural language query in the family history."""
#     results = retriever.get_relevant_documents(query)
#     return format_rag_contexts(results)  # Return formatted results instead of raw objects

@tool("translate_to_french")
def translate_to_french(query: str):
    """Translates the given query to French using OpenAI's `o4-mini` model to improve retriebal in French database."""
    
    response = openai.ChatCompletion.create(
        model="gpt-4o",  # "o4-mini" may refer to "gpt-4o"
        messages=[
            {"role": "system", "content": "You are a translation assistant."},
            {"role": "user", "content": f"Translate the following text to French:\n{query}"}
        ],
        temperature=0
    )

    return response

    

from typing import List
from langchain.tools import tool
import re


@tool("rag_search")
def rag_search(query: str):
    """Finds related information using a natural language query in the family history."""

    xq = encoder([query])
    xc = index.query(vector=xq, top_k=5, include_metadata=True)

    if "matches" not in xc or not xc["matches"]:
        return "⚠ No relevant documents found."

    # Extract best match details
    best_match = xc["matches"][0]
    chunk_id = best_match["metadata"].get("Chunk_ID", "")
    doc_name = best_match["metadata"].get("Doc name", "")
    total_chunks = best_match["metadata"].get("Total_Chunks", 1)  # Default to 1 if missing

    try:
        total_chunks = int(float(total_chunks))  # Ensure integer conversion from float or string
    except (ValueError, TypeError):
        total_chunks = 1  # Fallback in case of conversion error

    print(f"🔍 Best Match - Doc: {doc_name}, Chunk: {chunk_id}, Total Chunks: {total_chunks}")

    # Extract chunk number
    match = re.match(r"(.+)_Chunk(\d+)", chunk_id)
    if not match:
        return format_rag_contexts(xc["matches"])  # Return base context if extraction fails

    _, chunk_num = match.groups()

    try:
        chunk_num = int(chunk_num)  # Ensure chunk_num is an integer
    except ValueError:
        return format_rag_contexts(xc["matches"])  # Fallback in case of error

    # Debug: Print extracted chunk numbers before range calculation
    print(f"🔢 Extracted Chunk Number: {chunk_num}, Total Chunks: {total_chunks}")

    # Generate **bounded** chunk IDs within valid range
    min_chunk = max(1, chunk_num - 3)
    max_chunk = min(total_chunks, chunk_num + 3)

    # Debug: Check type before using in range
    print(f"🔍 Before Casting - min_chunk: {min_chunk} ({type(min_chunk)}), max_chunk: {max_chunk} ({type(max_chunk)})")

    # Ensure integer conversion
    min_chunk = int(min_chunk)
    max_chunk = int(max_chunk)

    # Debug: Confirm type after casting
    print(f"✅ After Casting - min_chunk: {min_chunk} ({type(min_chunk)}), max_chunk: {max_chunk} ({type(max_chunk)})")

    expanded_chunk_ids = [f"{doc_name}_Chunk{i}" for i in range(min_chunk, max_chunk + 1)]

    print(f"🧩 Expanding context with bounded chunks: {expanded_chunk_ids}")

    # Retrieve expanded chunks
    expanded_contexts = []
    for expanded_chunk in expanded_chunk_ids:
        try:
            result = chunk_search.run({"query": query, "chunk_id": expanded_chunk})
            if result and "⚠ No context found" not in result:
                expanded_contexts.append(result)
        except Exception as e:
            print(f"⚠ Error retrieving chunk {expanded_chunk}: {str(e)}")

    # Combine and return formatted context
    full_context = "\n\n".join(expanded_contexts) if expanded_contexts else format_rag_contexts(xc["matches"])
    return full_context






@tool("chunk_search")
def chunk_search(query: str, chunk_id: str):
    """Finds related information based on the chunk_id. Helps to get more context."""

    # Extract Doc Name and Chunk Number from chunk_id
    match = re.match(r"(.+)_Chunk(\d+)", chunk_id)
    if not match:
        return f"❌ Error: Invalid chunk_id format '{chunk_id}'"

    doc_name, chunk_number = match.groups()
    chunk_number = int(chunk_number)

    # Generate surrounding chunk IDs (-2, -1, +1, +2)
    chunk_ids = [f"{doc_name}_Chunk{i}" for i in range(chunk_number - 8, chunk_number + 8) if i > 0]

    print(f"🔍 Debugging Chunk IDs: {chunk_ids}")

    # Encode query into a vector (Replace `encoder()` with your actual embedding function)
    xq = encoder([query])  # Convert query into vector

    try:
        # Perform a **vector-based search** instead of only filtering by chunk ID
        response = index.query(
            vector=xq,
            namespace="",
            filter={"Chunk_ID": {"$in": chunk_ids}},  # Ensure correct filter usage
            top_k=15,  # Fetch relevant results
            include_metadata=True
        )
        direct_matches = response["matches"]

    except Exception as e:
        return f"❌ Pinecone Query Error: {str(e)}"

    # Format and return results
    results = []
    for match in direct_matches:
        metadata = match.get("metadata", {})
        chunk_text = metadata.get("text", "No content available")
        chunk_id_match = metadata.get("Chunk_ID", "Unknown Chunk")
        results.append(f"📜 Found Chunk: {chunk_id_match} -> {chunk_text}...")  # Limit text preview

    return "\n".join(results) if results else "⚠ No relevant chunks found."

# %%
rag_search.run("29 Mars 1963")
# Out:
# 🔍 Best Match - Doc: Pour la mémoire familiale 1-50, Chunk: Pour la mémoire familiale 1-50_Chunk1, Total Chunks: 2
# 🔢 Extracted Chunk Number: 1, Total Chunks: 2
# 🔍 Before Casting - min_chunk: 1 (<class 'int'>), max_chunk: 2 (<class 'int'>)
# ✅ After Casting - min_chunk: 1 (<class 'int'>), max_chunk: 2 (<class 'int'>)
# 🧩 Expanding context with bounded chunks: ['Pour la mémoire familiale 1-50_Chunk1', 'Pour la mémoire familiale 1-50_Chunk2']
# 🔍 Debugging Chunk IDs: ['Pour la mémoire familiale 1-50_Chunk1', 'Pour la mémoire familiale 1-50_Chunk2', 'Pour la mémoire familiale 1-50_Chunk3', 'Pour la mémoire familiale 1-50_Chunk4', 'Pour la mémoire familiale 1-50_Chunk5', 'Pour la mémoire familiale 1-50_Chunk6', 'Pour la mémoire familiale 1-50_Chunk7', 'Pour la mémoire familiale 1-50_Chunk8']
# 🔍 Debugging Chunk IDs: ['Pour la mémoire familiale 1-50_Chunk1', 'Pour la mémoire familiale 1-50_Chunk2', 'Pour la mémoire familiale 1-50_Chunk3', 'Pour la mémoire familiale 1-50_Chunk4', 'Pour la mémoire familiale 1-50_Chunk5', 'Pour la mémoire familiale 1-50_Chunk6', 'Pour la mémoire familiale 1-50_Chunk7', 'Pour la mémoire familiale 1-50_Chunk8', 'Pour la mémoire familiale 1-50_Chunk9']
# '📜 Found Chunk: Pour la mémoire familiale 1-50_Chunk1 -
n📜 Found Chunk: Pour la mémoire familiale 1-50_Chunk1 -> ne m\'a jamais dit que c\'était une mauvaise fréquentation, au contraire il l\'aimait beaucoup. Il n\'a\ncertainement jamais fait de remarque à Tonio à ce sujet. Je pense que pour lui, comme pour nous, cela ne\nvenait pas à l\'esprit.\n\nNous n\'aimions pas l\'Action Française. Moi bien sûr en raison de leur propagande\nantisémite, mais aussi des écrits haineux que répandait Charles Maurras dans toutes les directions, en\nraison également de la violence des "camelots du roi" (à l\'époque ils se battaient avec des cannes). De\ntoute façon nous ne comprenions rien à leurs positions. Ils se battaient pour un prétendant au trône, le\nComte de Paris, qui les rejetait, et pour l\'église catholique, qui les avait excommuniés. Mais en dehors de\ntoute politique je connaissais des gens d\'Action Française. Comme, malgré la propagande, il n\'y avait\npratiquement personne pour prendre au série ...

# %%
from langchain_core.messages import SystemMessage, AIMessage

@tool("report")
def report(
    introduction: str,
    research_steps: str,
    main_body: str,
    conclusion: str,
    sources: Union[str, List[str], None] = None
):
    """
    You are the family safe, keeper of the family collective memory.

    Returns a natural language response to the user's question based on the family memory database.

    Do not invent anything but you are allowed to link information together from multiple sources.
    """

    # Format the research steps and sources
    if isinstance(research_steps, list):
        research_steps = "\n".join([f"- {r}" for r in research_steps])
    if isinstance(sources, list):
        sources = "\n".join([f"- {s}" for s in sources])

    # System prompt to guide the final response
    system_prompt = SystemMessage(
        content=(
            "You are the family safe, the guardian of collective memory. "
            "Provide a detailed but concise summary based on the following sections: "
            "introduction, research steps, main body, and conclusion. "
            "Include sources if available and only use verified information."
            "Always make sure that conext was checked ussing **chunk_search**"
            "If you can't find an answer with sources, just say that you don't know."
        )
    )

    # Combine the sections into a message
    user_query_context = (
        f"### Introduction:\n{introduction}\n\n"
        f"### Research Steps:\n{research_steps}\n\n"
        f"### Main Body:\n{main_body}\n\n"
        f"### Conclusion:\n{conclusion}\n\n"
        f"### Sources:\n{sources if sources else 'No sources available.'}"
    )

    # Append the system prompt to messages and call the LLM
    messages = [system_prompt, AIMessage(content=user_query_context)]
    final_response = llm.invoke(messages)  # Call the LLM for a response

    return final_response

# %% [markdown]
# ## Final answer Template

# %%
from langchain_core.messages import SystemMessage, AIMessage

@tool("final_answer")
def final_answer(
    answer: str,
    explore_next: str,
    sources: Union[str, List[str], None] = None
):
    """
    You are the family safe, keeper of the family collective memory.

    Returns a natural language response to the user's question based on the family memory database.

    Do not invent anything but you are allowed to link information together from multiple sources.

    If you can't find an answer, just say that you don't know.
    """

    # Format the research steps and sources
    if isinstance(sources, list):
        sources = "\n".join([f"- {s}" for s in sources])

    # System prompt to guide the final response
    system_prompt = SystemMessage(
        content=(
            "You are the family safe, the guardian of collective memory. "
            "Provide a detailed but concise answer to the original query."
            "If a report is requested, use {'tool': 'report'} to find more information."
            "Include sources if available and only use verified information."
            "If you can't find an answer with sources just say that you don't know."
            "Always make sure that context was checked using {'tool': 'chunk_search'}"
            "Offer to explore more information with the 'explore_next' prompt."
            "Final answer must always be in English."
        )
    )

    # Combine the sections into a message
    user_query_context = (
        f"### Answer:\n{answer}\n\n"
        f"### Sources:\n{sources if sources else 'No sources available.'}"
        f"### Explore Next:\n{explore_next}"

    )

    # Append the system prompt to messages and call the LLM
    messages = [system_prompt, AIMessage(content=user_query_context)]
    final_response = llm.invoke(messages)  # Call the LLM for a response

    return final_response

# %% [markdown]
# ## Initialize Oracle (aka. Family keeper)

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

system_prompt = """You are the Family Safe, keeper of the family's collective memory. 
Your role is to decide how to handle user queries using the available tools.

**Tool Usage:**
- Do NOT reuse a tool for the same query (check the scratchpad).
- Do NOT use any tool more than **3 times**.
- Prioritize **rag_search** for gathering information.
- Use **chunk_search** to find context around a specific chunk.
- Do not mix sources from different contexts unless necessary.
- Alsways check at leats 2 ***Doc name*** to ensure the information is correct.

**Response Protocol:**
- If tools provides no answer, state that you don't know or can't any information about this topic"
- NEVER invent information or use data beyond the family memory.
- Always provide sources via the **final_answer** tool.
- Chunk_search must be in the scracthpad to point to final_answer.
- Discard any page content that looks like a table of content: you won't find any useful information there apart from page numbers.

By following these rules, you ensure accurate and responsible responses."""

prompt = ChatPromptTemplate.from_messages([
    ("system", system_prompt),
    MessagesPlaceholder(variable_name="chat_history"),
    ("user", "{input}"),
    ("assistant", "scratchpad: {scratchpad}"),
])

# %% [markdown]
# ## Initialize Agent

# %%
from langchain_core.messages import ToolCall, ToolMessage
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o-mini",
    openai_api_key = OPENAI_API_KEY,
    temperature=0
)

tools=[
    #simple_search,
    chunk_search,
    rag_search,
    report,
    # translate_to_french,
    final_answer
]

# define a function to transform intermediate_steps from list
# of AgentAction to scratchpad string
def create_scratchpad(intermediate_steps: list[AgentAction]):
    research_steps = []
    for i, action in enumerate(intermediate_steps):
        if action.log != "TBD":
            # this was the ToolExecution
            research_steps.append(
                f"Tool: {action.tool}, input: {action.tool_input}\n"
                f"Output: {action.log}"
            )
    return "\n---\n".join(research_steps)

oracle = (
    {
        "input": lambda x: x["input"],
        "chat_history": lambda x: x["chat_history"],
        "scratchpad": lambda x: create_scratchpad(
            intermediate_steps=x["intermediate_steps"]
        ),
    }
    | prompt
    | llm.bind_tools(tools, tool_choice="any")
)

# %% [markdown]
# ### Test agent

# %%
inputs = {
    "input": "tell me something interesting about the Dreyfus family",
    "chat_history": [],
    "intermediate_steps": [],
}
out = oracle.invoke(inputs)
out
# Out:
# AIMessage(content='', additional_kwargs={'tool_calls': [{'id': 'call_FrqehTvX1UQWcXv8zRwc1iLe', 'function': {'arguments': '{"query":"Dreyfus family"}', 'name': 'rag_search'}, 'type': 'function'}], 'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 19, 'prompt_tokens': 508, 'total_tokens': 527, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_72ed7ab54c', 'finish_reason': 'tool_calls', 'logprobs': None}, id='run-fea1ec04-4011-4910-94cf-8c3277991b81-0', tool_calls=[{'name': 'rag_search', 'args': {'query': 'Dreyfus family'}, 'id': 'call_FrqehTvX1UQWcXv8zRwc1iLe', 'type': 'tool_call'}], usage_metadata={'input_tokens': 508, 'output_tokens': 19, 'total_tokens': 527, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %% [markdown]
# ## Define Nodes for Graph

# %%
def run_oracle(state: list):
    print("run_oracle")
    print(f"intermediate_steps: {state['intermediate_steps']}")
    out = oracle.invoke(state)
    tool_name = out.tool_calls[0]["name"]
    tool_args = out.tool_calls[0]["args"]
    action_out = AgentAction(
        tool=tool_name,
        tool_input=tool_args,
        log="TBD"
    )
    return {
        "intermediate_steps": [action_out]
    }

def router (state: list): #Original
    # return the tool name to use
    if isinstance(state["intermediate_steps"], list):
        return state["intermediate_steps"][-1].tool
    else:
        # if we output bad format go to final answer
        print("Router invalid format")
#         return "final_answer"

# %%
tool_str_to_func = {
    "rag_search": rag_search,
    "report": report,
    #"simple_search": simple_search,
    "translate_to_french": translate_to_french,
    "chunk_search": chunk_search,
    "final_answer": final_answer
}

def run_tool(state: list):
    # use this as helper function so we repeat less code
    tool_name = state["intermediate_steps"][-1].tool
    tool_args = state["intermediate_steps"][-1].tool_input
    print(f"{tool_name}.invoke(input={tool_args})")
    # run tool
    out = tool_str_to_func[tool_name].invoke(input=tool_args)
    action_out = AgentAction(
        tool=tool_name,
        tool_input=tool_args,
        log=str(out)
    )
    return {"intermediate_steps": [action_out]}

# %% [markdown]
# ## Define graph

# %%
from langgraph.graph import StateGraph, END

graph = StateGraph(AgentState)

graph.add_node("oracle", run_oracle)
#graph.add_node("simple_search", run_tool)
# graph.add_node("translate_to_french", run_tool)
graph.add_node("rag_search", run_tool)
graph.add_node("chunk_search", run_tool)
graph.add_node("report", run_tool)
graph.add_node("final_answer", run_tool)

graph.set_entry_point("oracle")

graph.add_conditional_edges(
    source="oracle",  # where in graph to start
    path=router,  # function to determine which node is called
)

# create edges from each tool back to the oracle
for tool_obj in tools:
    if tool_obj.name != "final_answer":
        graph.add_edge(tool_obj.name, "oracle")

# if anything goes to final answer, it must then move to END
graph.add_edge("final_answer", END)

runnable = graph.compile()

# %% [markdown]
# ## Test agent

# %%
out = runnable.invoke({
    "input": "Qui est Jacques Drefyus?",
    "chat_history": [],
})
# Out:
# run_oracle
# intermediate_steps: []
# rag_search.invoke(input={'query': 'Jacques Drefyus'})
# 🔍 Best Match - Doc: Pdf img, Chunk: Pdf img_Chunk2, Total Chunks: 2
# 🔢 Extracted Chunk Number: 2, Total Chunks: 2
# 🔍 Before Casting - min_chunk: 1 (<class 'int'>), max_chunk: 2 (<class 'int'>)
# ✅ After Casting - min_chunk: 1 (<class 'int'>), max_chunk: 2 (<class 'int'>)
# 🧩 Expanding context with bounded chunks: ['Pdf img_Chunk1', 'Pdf img_Chunk2']
# 🔍 Debugging Chunk IDs: ['Pdf img_Chunk1', 'Pdf img_Chunk2', 'Pdf img_Chunk3', 'Pdf img_Chunk4', 'Pdf img_Chunk5', 'Pdf img_Chunk6', 'Pdf img_Chunk7', 'Pdf img_Chunk8']
# 🔍 Debugging Chunk IDs: ['Pdf img_Chunk1', 'Pdf img_Chunk2', 'Pdf img_Chunk3', 'Pdf img_Chunk4', 'Pdf img_Chunk5', 'Pdf img_Chunk6', 'Pdf img_Chunk7', 'Pdf img_Chunk8', 'Pdf img_Chunk9']
# run_oracle
# intermediate_steps: [AgentAction(tool='rag_search', tool_input={'query': 'Jacques Drefyus'}, log='TBD'), AgentAction(tool='rag_search', tool_input={'query': 'Jacques Drefyus'}, log="📜 Found Chunk: Pdf img_Chunk2 -> de Maman Michel, et il est mort à Reims le 4 mars 1893 âgé de soixante quatre ans.\n\nSon influence sur la famille est de plus courte durée que celle de Maman Michel, mais c'est aussi une forte personnalité qui a joué un rôle important dans le déroulement de la vie familiale.\n\nL'histoire de Jacques Dreyfus commence à l'époque où il exerçait la profession de colporteur. C'est le terme qu'employait mon père, mais je pense qu'il n'est pas exact, en raison de l'importance de son commerce. Je dirais plutôt négociant en tissus, en précisant qu'il l'exerçait en ambulant. Il avait pour cela une voiture à deux chevaux assez spacieuse et confortable. Il était propriétaire de l'ensemble, ce qui paraît assez rare dans cette profession à cette époque. Il faisait des tournées d'environ six mois et son itinéraire comportait beaucoup de petits bourgs qui n'étaient pas desservis par les diligences. C'est à dire qu'il voyageait en zigzag autour de la grande route. Il ne faisait pas les marchés, mais approvisionnait les revendeurs....\n📜 Found Chunk: Pdf img_Chunk1 -> C'est le dernier, Isaac, dit Hovel, le plus souvent appelé Louis qui est notre ancêtre direct à la génération suivante. Il est né en 1766 à Froeningen, et s'est marié avec Rachel (ou Reiche ou Rosalie ou Thérèse) Gugenheim, née également à Froeningen en 1772, et décédée dans le même village en 1843, à 81 ans.\n\nDu ménage Louis et Rachel, je connais six enfants: Charlotte ex Judele, Jacques ex Jacob, marchand de bestiaux, Alexandre ex Samuel, marchand de bestiaux, Lehmann ou Clément, Marx, marchand de bétail, et Julie ex Sara, tous nés à Froeningen entre 1795 et 1802.\n\nParmi eux, notre ancêtre direct est Lehmann, sur son prénom je note qu'en 1808 il devient Clément, mais que seul le prénom de Lehmann continuera à être employé par la suite. Il est né en 1800 à Froeningen, et décédé au même lieu en 1843. En 1827 il a épousé Athelle (ou Adèle, ou Esther) Bloch, née à Soultz, village proche de Froeningen, en 1803, que j'ai déjà mentionnée.\n\nLehmann et Adèle ont eu neuf enfants dont j'ai connaissance, tous nés à Froeningen, et qui sont: Gabriel né le 3/2/1828 et décédé six semaines plus tard, Jacques né le 9 janvier 1829, Sophie née le 4/10/1830, Louise née le 27/7/1832, Sara ou Charlotte née le 12/8/1834, Marx ou Michel né le 26/4/1836, Cerf ou Hirtz né le 14/11/1838, Judith née en 1840, et Samuel né le 22/4/1843.\n\nJ'ai eu beaucoup de mal avec leur instabilité de prénoms. Bien que mon père les ai connu à la fin du XIXe siècle, il parle de certains sous un prénom, et retrouvant d'autres noms sur des papiers divers, j'ai pensé par moment qu'il devaient être plus nombreux. Mais quand, par exemple, il a manqué des noms sur des papiers de succession, il y avait évidemment des impossibilités. Alors qui était qui?...je n'ai pas trouvé tout de suite.\n\nParmi eux notre ascendant direct est Jacques Dreyfus, qui est en fait l'aîné de la famille. Je vais parler de lui et de ses frères et soeurs plus en détail, car c'est une génération que mon père a connue.\n\n-Jacques Dreyfus.\n\nJacques Dreyfus avait quarante huit ans à la naissance de son père, qui a bien connu son grand-père.\n\nJacques Dreyfus est né à Froeningen le 9 janvier 1829. C'est au moins la troisième génération venue au monde dans ce village. Il s'est marié le 4 juillet 1860 à Reims avec Catherine Lévy, fille de Maman Michel, et il est mort à Reims le 4 mars 1893 âgé de soixante quatre ans.\n\nSon influence sur la famille est de plus courte durée que celle de Maman Michel, mais c'est aussi une forte personnalité qui a joué un rôle important dans le déroulement de la vie familiale.\n\nL'histoire de Jacques Dreyfus commence à l'époque où il exerçait la profession de colporteur. C'est le terme qu'employait mon père,  ...
# final_answer.invoke(input={'answer': "Jacques Dreyfus est né le 9 janvier 1829 à Froeningen, et il est l'aîné de sa famille. Il s'est marié le 4 juillet 1860 à Reims avec Catherine Lévy, fille de Maman Michel. Jacques Dreyfus est décédé à Reims le 4 mars 1893, à l'âge de 64 ans. Il a exercé la profession de négociant en tissus, voyageant en ambulant avec une voiture à deux chevaux. Son influence sur la famille a été significative, bien que de plus courte durée que celle de Maman Michel.", 'explore_next': 'Souhaitez-vous en savoir plus sur la famille Dreyfus ou sur un autre membre de la famille?', 'sources': ['Pdf img_Chunk1', 'Pdf img_Chunk2']})

# %%
out = runnable.invoke({
    "input": "Who is Jacques Drefyus?",
    "chat_history": [],
})
# Out:
# run_oracle
# intermediate_steps: []
# rag_search.invoke(input={'query': 'Jacques Drefyus'})
# 🔍 Best Match - Doc: Pdf img, Chunk: Pdf img_Chunk2, Total Chunks: 2
# 🔢 Extracted Chunk Number: 2, Total Chunks: 2
# 🔍 Before Casting - min_chunk: 1 (<class 'int'>), max_chunk: 2 (<class 'int'>)
# ✅ After Casting - min_chunk: 1 (<class 'int'>), max_chunk: 2 (<class 'int'>)
# 🧩 Expanding context with bounded chunks: ['Pdf img_Chunk1', 'Pdf img_Chunk2']
# 🔍 Debugging Chunk IDs: ['Pdf img_Chunk1', 'Pdf img_Chunk2', 'Pdf img_Chunk3', 'Pdf img_Chunk4', 'Pdf img_Chunk5', 'Pdf img_Chunk6', 'Pdf img_Chunk7', 'Pdf img_Chunk8']
# 🔍 Debugging Chunk IDs: ['Pdf img_Chunk1', 'Pdf img_Chunk2', 'Pdf img_Chunk3', 'Pdf img_Chunk4', 'Pdf img_Chunk5', 'Pdf img_Chunk6', 'Pdf img_Chunk7', 'Pdf img_Chunk8', 'Pdf img_Chunk9']
# run_oracle
# intermediate_steps: [AgentAction(tool='rag_search', tool_input={'query': 'Jacques Drefyus'}, log='TBD'), AgentAction(tool='rag_search', tool_input={'query': 'Jacques Drefyus'}, log="📜 Found Chunk: Pdf img_Chunk2 -> de Maman Michel, et il est mort à Reims le 4 mars 1893 âgé de soixante quatre ans.\n\nSon influence sur la famille est de plus courte durée que celle de Maman Michel, mais c'est aussi une forte personnalité qui a joué un rôle important dans le déroulement de la vie familiale.\n\nL'histoire de Jacques Dreyfus commence à l'époque où il exerçait la profession de colporteur. C'est le terme qu'employait mon père, mais je pense qu'il n'est pas exact, en raison de l'importance de son commerce. Je dirais plutôt négociant en tissus, en précisant qu'il l'exerçait en ambulant. Il avait pour cela une voiture à deux chevaux assez spacieuse et confortable. Il était propriétaire de l'ensemble, ce qui paraît assez rare dans cette profession à cette époque. Il faisait des tournées d'environ six mois et son itinéraire comportait beaucoup de petits bourgs qui n'étaient pas desservis par les diligences. C'est à dire qu'il voyageait en zigzag autour de la grande route. Il ne faisait pas les marchés, mais approvisionnait les revendeurs....\n📜 Found Chunk: Pdf img_Chunk1 -> C'est le dernier, Isaac, dit Hovel, le plus souvent appelé Louis qui est notre ancêtre direct à la génération suivante. Il est né en 1766 à Froeningen, et s'est marié avec Rachel (ou Reiche ou Rosalie ou Thérèse) Gugenheim, née également à Froeningen en 1772, et décédée dans le même village en 1843, à 81 ans.\n\nDu ménage Louis et Rachel, je connais six enfants: Charlotte ex Judele, Jacques ex Jacob, marchand de bestiaux, Alexandre ex Samuel, marchand de bestiaux, Lehmann ou Clément, Marx, marchand de bétail, et Julie ex Sara, tous nés à Froeningen entre 1795 et 1802.\n\nParmi eux, notre ancêtre direct est Lehmann, sur son prénom je note qu'en 1808 il devient Clément, mais que seul le prénom de Lehmann continuera à être employé par la suite. Il est né en 1800 à Froeningen, et décédé au même lieu en 1843. En 1827 il a épousé Athelle (ou Adèle, ou Esther) Bloch, née à Soultz, village proche de Froeningen, en 1803, que j'ai déjà mentionnée.\n\nLehmann et Adèle ont eu neuf enfants dont j'ai connaissance, tous nés à Froeningen, et qui sont: Gabriel né le 3/2/1828 et décédé six semaines plus tard, Jacques né le 9 janvier 1829, Sophie née le 4/10/1830, Louise née le 27/7/1832, Sara ou Charlotte née le 12/8/1834, Marx ou Michel né le 26/4/1836, Cerf ou Hirtz né le 14/11/1838, Judith née en 1840, et Samuel né le 22/4/1843.\n\nJ'ai eu beaucoup de mal avec leur instabilité de prénoms. Bien que mon père les ai connu à la fin du XIXe siècle, il parle de certains sous un prénom, et retrouvant d'autres noms sur des papiers divers, j'ai pensé par moment qu'il devaient être plus nombreux. Mais quand, par exemple, il a manqué des noms sur des papiers de succession, il y avait évidemment des impossibilités. Alors qui était qui?...je n'ai pas trouvé tout de suite.\n\nParmi eux notre ascendant direct est Jacques Dreyfus, qui est en fait l'aîné de la famille. Je vais parler de lui et de ses frères et soeurs plus en détail, car c'est une génération que mon père a connue.\n\n-Jacques Dreyfus.\n\nJacques Dreyfus avait quarante huit ans à la naissance de son père, qui a bien connu son grand-père.\n\nJacques Dreyfus est né à Froeningen le 9 janvier 1829. C'est au moins la troisième génération venue au monde dans ce village. Il s'est marié le 4 juillet 1860 à Reims avec Catherine Lévy, fille de Maman Michel, et il est mort à Reims le 4 mars 1893 âgé de soixante quatre ans.\n\nSon influence sur la famille est de plus courte durée que celle de Maman Michel, mais c'est aussi une forte personnalité qui a joué un rôle important dans le déroulement de la vie familiale.\n\nL'histoire de Jacques Dreyfus commence à l'époque où il exerçait la profession de colporteur. C'est le terme qu'employait mon père,  ...
# final_answer.invoke(input={'answer': 'Jacques Dreyfus was born on January 9, 1829, in Froeningen, making him part of at least the third generation born in that village. He married Catherine Lévy on July 4, 1860, in Reims, and passed away in Reims on March 4, 1893, at the age of 64. Dreyfus was known for his strong personality and played a significant role in the family dynamics, although his influence was shorter than that of Maman Michel. He worked as a traveling merchant, specifically in textiles, using a spacious two-horse carriage for his business, which involved traveling to small towns not served by stagecoaches. His profession was more accurately described as a fabric trader rather than a simple peddler, as he had a notable level of commerce for that time.', 'explore_next': 'Would you like to know more about his family or his descendants?', 'sources': ['Pdf img_Chunk1', 'Pdf img_Chunk2']})

# %%
out = runnable.invoke({
    "input": "Do we have info about La Belle au bois dormant in the family database?",
    "chat_history": []
})
# Out:
# run_oracle
# intermediate_steps: []
# rag_search.invoke(input={'query': 'La Belle au bois dormant'})
# 🔍 Best Match - Doc: Pour la mémoire familiale 1-50, Chunk: Pour la mémoire familiale 1-50_Chunk1, Total Chunks: 1
# 🔢 Extracted Chunk Number: 1, Total Chunks: 1
# 🔍 Before Casting - min_chunk: 1 (<class 'int'>), max_chunk: 1 (<class 'int'>)
# ✅ After Casting - min_chunk: 1 (<class 'int'>), max_chunk: 1 (<class 'int'>)
# 🧩 Expanding context with bounded chunks: ['Pour la mémoire familiale 1-50_Chunk1']
# 🔍 Debugging Chunk IDs: ['Pour la mémoire familiale 1-50_Chunk1', 'Pour la mémoire familiale 1-50_Chunk2', 'Pour la mémoire familiale 1-50_Chunk3', 'Pour la mémoire familiale 1-50_Chunk4', 'Pour la mémoire familiale 1-50_Chunk5', 'Pour la mémoire familiale 1-50_Chunk6', 'Pour la mémoire familiale 1-50_Chunk7', 'Pour la mémoire familiale 1-50_Chunk8']
# run_oracle
# intermediate_steps: [AgentAction(tool='rag_search', tool_input={'query': 'La Belle au bois dormant'}, log='TBD'), AgentAction(tool='rag_search', tool_input={'query': 'La Belle au bois dormant'}, log='📜 Found Chunk: Pour la mémoire familiale 1-50_Chunk1 -> POUR LA MEMOIRE FAMILIALE\nFAMILLE HISTOIRE SOUVENIRS & COMMENTAIRES\n+++++\nTOME I\n***\nMA FAMILLE PATERNELLE\n************\n10...\n📜 Found Chunk: Pour la mémoire familiale 1-50_Chunk1 -> POUR LA MÉMOIRE\nFAMILIALE\n\nFAMILLE HISTOIRE\nSOUVENIRS & COMMENTAIRES\n\nVOLUME 1\n\nJean-Georges Lambert\nAvril 1993...\n📜 Found Chunk: Pour la mémoire familiale 1-50_Chunk1 -> vieillots, et quand je les entendais d\'une oreille\ndistraite il m\'en restait bien peu en mémoire. Il a fallu\nla disparition de ma mère pour que je m\'aperçoive que\nj\'ignorais même qui étaient les personnages représentés par\nles tableaux de famille que j\'avais vus durant toute mon\nenfance sans vraiment les regarder. Ce n\'était pas de\nl\'indifférence, mais Maman le savait et cela me suffisait.\nAlors je me suis lancé dans l\'étude de ces\ndocuments et dans la constitution d\'un arbre généalogique à\npartir des éléments dont je disposais. En même temps je\ndemandais à mon père qui vivait encore de réunir pour moi\ntout ce qu\'il connaissait de sa famille.\nA ce moment j\'ai pensé pour la première fois à\néviter que tout soit perdu de la même façon pour mes fils,\ncar je pouvais encore sauver une partie de la mémoire de la\nfamille en faisant appel à mes souvenirs et à ceux de ma\nsoeur pour faire revivre un certain nombre de documents qui\nperdraient toute signification après nous.\nEt puis j\'ai été repris par les nécessités de\nl\'existence et j\'ai fermé ces dossiers jusqu\'à maintenant.\nPourtant je n\'ai pas oublié cette idée qui\ns\'est renforcée lorsque j\'ai réalisé, qu\'en raison de l\'âge\nde mes parents, mes fils ont très peu connu leurs grands-\nparents paternels. Ma mère est morte le 29 mars 1963.\nA cette date William n\'était pas né, Georges avait treize...\n📜 Found Chunk: Pour la mémoire familiale 1-50_Chunk1 -> 18\n\nPREMIÈRE PARTIE\n\nPOUR FAIRE LE POINT\nAU TEMPS DE MA JEUNESSE...\n📜 Found Chunk: Pour la mémoire familiale 1-50_Chunk1 -> sont pas seuls visés par cette campagne Mon père et l\'antisémitisme avant l\'affaire\nDrevfus L\'Affaire Dreyfus Mon père dans l\'affaire Dreyfus Le point de vue de mon\npère sur l\'affaire Drevdus-\n168 -Chapitre XXV :-Sa vie privée de 1903 à 1914\nSon premier mariage. Les relations féminines Ses revenus Mon père et sa famille -\n170 -Chapitre XXVI:-Sa vie professionnelle de 1903 à 1914.\nSon activité chez Jansen Activités diverses Les affaires de construction -\n175 -Chapitre XXVII: La querre de 1914-1918\n181 ANNEXES I & II\n- La situation militaire de mon père Les étapes de la querre de mon père -Première\npériode, août 1914-janvier 1916 -Deuxième période, février 1916-mai 1919 -La guerre vue\nau travers du courrier -Portraits et anecdotes écrits par mon père Comment mon père a\nrencontré ma mère pendant la querre.\n182 -Annexe I Notes et réflexions à la suite de mes lectures.\n183\nAvertissement.\n184 Réflexions sur les rapports entre l\'Eglise et le juifs Contradictions et ambiguités.\n191\nRacisme et antisémitisme\n195\nJuifs ou Israelites.\n199\nLes juifs éternels persécutés.\n201 Les juifs pendant 4.000 ans.\n209\n211\nJudaisme, humanisme, droits de l\'homme et démocratie.\nNotes diverses: Les noms juifs Napoléon et les juifs Les officiers juifs dans l\'armée française\nau temps de l\'affaire Dreyfus.\n215 Les juifs dans l\'histoire de France et l\'apport des juifs dans notre civilisation.\n217 -Annexe II - Quelques écrits de mon père.\n218\nPrésentation\n219 Au temps des diligences\n220 La Belle Epoque à Reims\n222\nSouvenirs à bâtons romous (Stavisky)\n224 La musique du régiment à Nancy\n225 Les Passagères\nVOLUME 2\n- ANNEXES III A VIII - DOCUMENTS -\n-Annexe III: Cartes\n-Annexe IV: Généalogie\n-Annexe V: Photos & Caricatures\n-Annexe VI:  ...
# final_answer.invoke(input={'answer': 'I don\'t have any information about "La Belle au bois dormant" in the family database.', 'explore_next': 'Would you like to ask about another topic?', 'sources': None})

# %%
out = runnable.invoke({
    "input": "Qui est Francis?",
    "chat_history": []
})
# Out:
# run_oracle
# intermediate_steps: []
# rag_search.invoke(input={'query': 'Francis'})
# 🔍 Best Match - Doc: Pour la mémoire familiale 1-50, Chunk: Pour la mémoire familiale 1-50_Chunk2, Total Chunks: 2
# 🔢 Extracted Chunk Number: 2, Total Chunks: 2
# 🔍 Before Casting - min_chunk: 1 (<class 'int'>), max_chunk: 2 (<class 'int'>)
# ✅ After Casting - min_chunk: 1 (<class 'int'>), max_chunk: 2 (<class 'int'>)
# 🧩 Expanding context with bounded chunks: ['Pour la mémoire familiale 1-50_Chunk1', 'Pour la mémoire familiale 1-50_Chunk2']
# 🔍 Debugging Chunk IDs: ['Pour la mémoire familiale 1-50_Chunk1', 'Pour la mémoire familiale 1-50_Chunk2', 'Pour la mémoire familiale 1-50_Chunk3', 'Pour la mémoire familiale 1-50_Chunk4', 'Pour la mémoire familiale 1-50_Chunk5', 'Pour la mémoire familiale 1-50_Chunk6', 'Pour la mémoire familiale 1-50_Chunk7', 'Pour la mémoire familiale 1-50_Chunk8']
# 🔍 Debugging Chunk IDs: ['Pour la mémoire familiale 1-50_Chunk1', 'Pour la mémoire familiale 1-50_Chunk2', 'Pour la mémoire familiale 1-50_Chunk3', 'Pour la mémoire familiale 1-50_Chunk4', 'Pour la mémoire familiale 1-50_Chunk5', 'Pour la mémoire familiale 1-50_Chunk6', 'Pour la mémoire familiale 1-50_Chunk7', 'Pour la mémoire familiale 1-50_Chunk8', 'Pour la mémoire familiale 1-50_Chunk9']
# run_oracle
# intermediate_steps: [AgentAction(tool='rag_search', tool_input={'query': 'Francis'}, log='TBD'), AgentAction(tool='rag_search', tool_input={'query': 'Francis'}, log='📜 Found Chunk: Pour la mémoire familiale 1-50_Chunk2 -
# final_answer.invoke(input={'answer': "Je ne dispose pas d'informations spécifiques sur une personne nommée Francis. Si vous avez des détails supplémentaires ou un contexte particulier concernant Francis, je pourrais peut-être vous aider davantage.", 'explore_next': "Si vous avez d'autres questions ou un autre sujet en tête, n'hésitez pas à demander !", 'sources': None})

# %%
out = runnable.invoke({
    "input": "Qui sont les 4 frères de Francis?",
    "chat_history": [],
})
# Out:
# run_oracle
# intermediate_steps: []
# rag_search.invoke(input={'query': 'frères de Francis'})
# 🔍 Best Match - Doc: Pour la mémoire familiale 1-50, Chunk: Pour la mémoire familiale 1-50_Chunk2, Total Chunks: 2
# 🔢 Extracted Chunk Number: 2, Total Chunks: 2
# 🔍 Before Casting - min_chunk: 1 (<class 'int'>), max_chunk: 2 (<class 'int'>)
# ✅ After Casting - min_chunk: 1 (<class 'int'>), max_chunk: 2 (<class 'int'>)
# 🧩 Expanding context with bounded chunks: ['Pour la mémoire familiale 1-50_Chunk1', 'Pour la mémoire familiale 1-50_Chunk2']
# 🔍 Debugging Chunk IDs: ['Pour la mémoire familiale 1-50_Chunk1', 'Pour la mémoire familiale 1-50_Chunk2', 'Pour la mémoire familiale 1-50_Chunk3', 'Pour la mémoire familiale 1-50_Chunk4', 'Pour la mémoire familiale 1-50_Chunk5', 'Pour la mémoire familiale 1-50_Chunk6', 'Pour la mémoire familiale 1-50_Chunk7', 'Pour la mémoire familiale 1-50_Chunk8']
# 🔍 Debugging Chunk IDs: ['Pour la mémoire familiale 1-50_Chunk1', 'Pour la mémoire familiale 1-50_Chunk2', 'Pour la mémoire familiale 1-50_Chunk3', 'Pour la mémoire familiale 1-50_Chunk4', 'Pour la mémoire familiale 1-50_Chunk5', 'Pour la mémoire familiale 1-50_Chunk6', 'Pour la mémoire familiale 1-50_Chunk7', 'Pour la mémoire familiale 1-50_Chunk8', 'Pour la mémoire familiale 1-50_Chunk9']
# run_oracle
# intermediate_steps: [AgentAction(tool='rag_search', tool_input={'query': 'frères de Francis'}, log='TBD'), AgentAction(tool='rag_search', tool_input={'query': 'frères de Francis'}, log='📜 Found Chunk: Pour la mémoire familiale 1-50_Chunk2 -> est très faible dans ces groupes. Le crypto-judaisme les a marqué au point que le Talmud est souvent oublié, et les ouvrages profanes sont souvent préférés à la littérature juive.\n\nAu point de vue fonctionnement, les communautés sont dirigées par un conseil des anciens, lesquels sont élus par quatre classes de fortune. Il réparti et lève l\'impôt qui est très lourd, et représente la communauté auprès des autorités.\n\nCette histoire des aarranes ne serait pas complète si on ne mentionnait pas ceux qui ont adhéré totalement au christianisme. Certains d\'entre eux parvinrent jusque dans l\'entourage royal, y conclurent des mariages et devinrent célèbres. On cite par exemple la famille de Bernuy dont un membre aida François 1º à payer sa rançon à Charles Quint, et un autre qui a fait obtenir les lettres patentes aux marchands portugais. Et pour la petite histoire, on peut citer aussi la mère de Montaigne, dont la famille marrane avait abandonné le judaisme....\n📜 Found Chunk: Pour la mémoire familiale 1-50_Chunk1 -> sont pas seuls visés par cette campagne Mon père et l\'antisémitisme avant l\'affaire\nDrevfus L\'Affaire Dreyfus Mon père dans l\'affaire Dreyfus Le point de vue de mon\npère sur l\'affaire Drevdus-\n168 -Chapitre XXV :-Sa vie privée de 1903 à 1914\nSon premier mariage. Les relations féminines Ses revenus Mon père et sa famille -\n170 -Chapitre XXVI:-Sa vie professionnelle de 1903 à 1914.\nSon activité chez Jansen Activités diverses Les affaires de construction -\n175 -Chapitre XXVII: La querre de 1914-1918\n181 ANNEXES I & II\n- La situation militaire de mon père Les étapes de la querre de mon père -Première\npériode, août 1914-janvier 1916 -Deuxième période, février 1916-mai 1919 -La guerre vue\nau travers du courrier -Portraits et anecdotes écrits par mon père Comment mon père a\nrencontré ma mère pendant la querre.\n182 -Annexe I Notes et réflexions à la suite de mes lectures.\n183\nAvertissement.\n184 Réflexions sur les rapports entre l\'Eglise et le juifs Contradictions et ambiguités.\n191\nRacisme et antisémitisme\n195\nJuifs ou Israelites.\n199\nLes juifs éternels persécutés.\n201 Les juifs pendant 4.000 ans.\n209\n211\nJudaisme, humanisme, droits de l\'homme et démocratie.\nNotes diverses: Les noms juifs Napoléon et les juifs Les officiers juifs dans l\'armée française\nau temps de l\'affaire Dreyfus.\n215 Les juifs dans l\'histoire de France et l\'apport des juifs dans notre civilisation.\n217 -Annexe II - Quelques écrits de mon père.\n218\nPrésentation\n219 Au temps des diligences\n220 La Belle Epoque à Reims\n222\nSouvenirs à bâtons romous (Stavisky)
sans abandonner l\'essentiel des privilèges de leur communauté. Leur position est d\'ailleurs justifiée car cela a été admis pour ceux du sud-ouest. On peut aussi comprendre que, dans le climat qui existe localement, la peur puisse leur faire craindre de perdre cette protection. Et il y a aussi les rabbins et les syndics qui ne veulent rien abandonner de leur autorité sur des communautés qui parfois les discutent\nOn arrive au 27 septembre 1791, l\'Assemblée Constituante doit être dissoute quelques jours plus tard, le Roi a été arrêté à Varennes en juin, et, parmi les députés hostiles aux juifs, beaucoup ont ésigré ou ne fréquentent plus l\'Assemblée. C\'est dans ce contexte que, presque à l\'improviste, le député Adrien Le Port, élu de la noblesse de Paris, intervient pour que l\'Assemblée accorde aux juifs tous les droits des citoyens. Le Président de séance, Regnault de Saint-Angély, intervient alors pour aenacer "tous ceux qui parlerant contre cette proposition, car c\'est la Constitution elle même qu\'ils combattront". La proposition est alors adoptée par cette assemblée à effectif réduit.\nPour l\'histoire officielle l\'égalité des juifs est acquise ce jour là.\nOn oublie que dès le lendemain du vote,...\n📜 Found Chunk: Pour la mémoire familiale 1-50_Chunk2 -> pour rester français.\n\nMon père et ses amis de sa génération avait fait la guerre de 1914-1918 contre "les\nboches". Ils nous répétaient les histoires de Verdun, de Douaumont, du Chemin des Dames.....\n\nJ\'ai grandi dans la vénération des héros de la guerre de 1914, Joffre, Foch, Clémenceau...A\nleur décès le gouverneme ...
# final_answer.invoke(input={'answer': "Ma mère est morte le 29 mars 1963. À cette date, William n'était pas encore né, et Georges avait treize ans.", 'explore_next': 'Souhaitez-vous en savoir plus sur ma mère ou sur un autre sujet lié à la famille ?', 'sources': ['Pour la mémoire familiale 1-50_Chunk2']})

# %%
out = runnable.invoke({
    "input": "Hello",
    "chat_history": []
})
# Out:
# run_oracle
# intermediate_steps: []
# final_answer.invoke(input={'answer': 'Hello! How can I assist you today?', 'explore_next': 'Feel free to ask any questions you have about family history or memories.', 'sources': None})

# %%
out = runnable.invoke({
    "input": "Fill me in on the intro of Pour la mémoire familiale 1-50",
    "chat_history": []
})
# Out:
# run_oracle
# intermediate_steps: []
# rag_search.invoke(input={'query': 'Pour la mémoire familiale 1-50 introduction'})
# 🔍 Best Match - Doc: Pour la mémoire familiale 1-50, Chunk: Pour la mémoire familiale 1-50_Chunk1, Total Chunks: 1
# 🔢 Extracted Chunk Number: 1, Total Chunks: 1
# 🔍 Before Casting - min_chunk: 1 (<class 'int'>), max_chunk: 1 (<class 'int'>)
# ✅ After Casting - min_chunk: 1 (<class 'int'>), max_chunk: 1 (<class 'int'>)
# 🧩 Expanding context with bounded chunks: ['Pour la mémoire familiale 1-50_Chunk1']
# 🔍 Debugging Chunk IDs: ['Pour la mémoire familiale 1-50_Chunk1', 'Pour la mémoire familiale 1-50_Chunk2', 'Pour la mémoire familiale 1-50_Chunk3', 'Pour la mémoire familiale 1-50_Chunk4', 'Pour la mémoire familiale 1-50_Chunk5', 'Pour la mémoire familiale 1-50_Chunk6', 'Pour la mémoire familiale 1-50_Chunk7', 'Pour la mémoire familiale 1-50_Chunk8']
# run_oracle
# intermediate_steps: [AgentAction(tool='rag_search', tool_input={'query': 'Pour la mémoire familiale 1-50 introduction'}, log='TBD'), AgentAction(tool='rag_search', tool_input={'query': 'Pour la mémoire familiale 1-50 introduction'}, log='📜 Found Chunk: Pour la mémoire familiale 1-50_Chunk1 -> POUR LA MEMOIRE FAMILIALE\nFAMILLE HISTOIRE SOUVENIRS & COMMENTAIRES\n+++++\nTOME I\n***\nMA FAMILLE PATERNELLE\n************\n10...\n📜 Found Chunk: Pour la mémoire familiale 1-50_Chunk1 -> POUR LA MÉMOIRE\nFAMILIALE\n\nFAMILLE HISTOIRE\nSOUVENIRS & COMMENTAIRES\n\nVOLUME 1\n\nJean-Georges Lambert\nAvril 1993...\n📜 Found Chunk: Pour la mémoire familiale 1-50_Chunk1 -> vieillots, et quand je les entendais d\'une oreille\ndistraite il m\'en restait bien peu en mémoire. Il a fallu\nla disparition de ma mère pour que je m\'aperçoive que\nj\'ignorais même qui étaient les personnages représentés par\nles tableaux de famille que j\'avais vus durant toute mon\nenfance sans vraiment les regarder. Ce n\'était pas de\nl\'indifférence, mais Maman le savait et cela me suffisait.\nAlors je me suis lancé dans l\'étude de ces\ndocuments et dans la constitution d\'un arbre généalogique à\npartir des éléments dont je disposais. En même temps je\ndemandais à mon père qui vivait encore de réunir pour moi\ntout ce qu\'il connaissait de sa famille.\nA ce moment j\'ai pensé pour la première fois à\néviter que tout soit perdu de la même façon pour mes fils,\ncar je pouvais encore sauver une partie de la mémoire de la\nfamille en faisant appel à mes souvenirs et à ceux de ma\nsoeur pour faire revivre un certain nombre de documents qui\nperdraient toute signification après nous.\nEt puis j\'ai été repris par les nécessités de\nl\'existence et j\'ai fermé ces dossiers jusqu\'à maintenant.\nPourtant je n\'ai pas oublié cette idée qui\ns\'est renforcée lorsque j\'ai réalisé, qu\'en raison de l\'âge\nde mes parents, mes fils ont très peu connu leurs grands-\nparents paternels. Ma mère est morte le 29 mars 1963.\nA cette date William n\'était pas né, Georges avait treize...\n📜 Found Chunk: Pour la mémoire familiale 1-50_Chunk1 -> PREAMBULE DU TOME I\n\n11\n\nIl y a maintenant près de six ans que j\'ai écrit le préambule que vous avez pu lire en tête de cet ouvrage. A ce moment je ne me méfiais pas de l\'aventure dans laquelle je me lançais. Je pensais alors qu\'il ne suffirait de mettre en ordre les documents et informations sur la famille, pour vous les transmettre sous une forme compréhensible. Et cela à la fois pour mes ascendants maternels et paternels. Six ans après je n\'ai traité, dans les pages qui suivent, que de ma famille paternelle et de son père, et seulement jusqu\'à la fin de la guerre de 1914/1918.\n\nLe hasard a voulu que je commence par les dossiers de mon père, et je suis tombé sur une richesse de documents de toutes sortes dont je ne soupçonnais pas l\'ampleur. Il s\'agissait surtout de centaines de notes prises sur des bouts de papiers, mêlées à des textes de lui, écrits, tantôt à la main, tantôt à la machine. La plus grande partie de ces notes étaient destinées à un ouvrage dont la bibliographie établie par lui énumérait, sur dix sept pages manuscrites, environ trois cents ouvrages et documents. Mais après avoir fait un travail considérable, il a finalement abandonné son projet.\n\nMélangé à tout cela, d\'autres notes et écrits traitaient de sujets divers, à partir d\'anecdotes vécues ou de pure imagination, quelquefois sous forme de divertissement. Et, au milieu de tout ce qui précède, pas mal de notes concernant la famille, et constituant, après classement, un ensemble riche qui s\'a servi à écrire une bonne partie de ce que vous trouverez dans les pages suivantes.\n\nCompte tenu de ses objectifs du moment, j\'ai trié en priorité ce qui concernait la famille. Mais ce tri nécessitait un énorme travail, car la grande majorité de ces centaines de notes et récits divers sont manuscrits, et l\'écriture de mon père nécessite un effort de déchiffrage t ...
# final_answer.invoke(input={'answer': 'L\'introduction de "Pour la mémoire familiale 1-50" aborde la quête de mémoire et d\'identité familiale de l\'auteur, Jean-Georges Lambert. Il commence par évoquer la perte de sa mère, qui a suscité en lui une prise de conscience de l\'importance de préserver l\'histoire familiale. Il se rend compte qu\'il ne connaît pas bien les personnages représentés dans les tableaux de famille et décide de constituer un arbre généalogique et de rassembler des souvenirs de son père. L\'auteur exprime son désir de transmettre cette mémoire à ses fils, afin qu\'ils ne subissent pas la même perte d\'identité. Au fil des années, il a accumulé des documents et des notes de son père, qui contiennent une richesse d\'informations sur leur histoire familiale, mais il a également constaté la difficulté de trier et de comprendre ces écrits. L\'introduction souligne l\'importance de la mémoire familiale et la nécessité de la transmettre aux générations futures, tout en reconnaissant les défis que cela implique.', 'explore_next': 'Would you like to know more about specific sections or themes in this work?', 'sources': ['Pour la mémoire familiale 1-50_Chunk1', 'Pour la mémoire familiale 1-50_Chunk2']})

# %% [markdown]
# ## Gradio

# %%
# Install necessary dependencies if needed
# %pip install --upgrade gradio langchain langgraph openai

import gradio as gr
import re
import ast

def extract_and_format_final_answer(data):
    """
    Extracts the latest `final_answer` from intermediate_steps in the given data,
    then formats and returns it in a structured output.

    Args:
        data (dict): The dictionary containing the 'intermediate_steps' list.

    Returns:
        str: A formatted string containing <answer> and <explore next>, and optionally <source>.
    """
    # Extract only the steps where tool == 'final_answer'
    final_answers = [step for step in data.get("intermediate_steps", []) if step.tool == "final_answer"]

    # Get the latest final answer and convert to string
    if not final_answers:
        return "⚠ No final answer found."
    
    log_string = str(final_answers[-1])

    # Extracting the tool_input dictionary using regex
    match = re.search(r"tool_input=({.*?})", log_string)
    if not match:
        return "⚠ No valid final answer found."

    # Convert the extracted string to a dictionary
    try:
        tool_input = ast.literal_eval(match.group(1))  # Safely convert string to dictionary
    except (SyntaxError, ValueError):
        return "⚠ Error parsing tool input."

    # Extract required fields
    answer = tool_input.get('answer', 'No answer provided.')
    sources = tool_input.get('sources', None)  # Keep None instead of default text
    explore_next = tool_input.get('explore_next', 'No further suggestions.')

    # Construct the formatted output
    formatted_output = f"{answer}\n"

    # Append source only if it's not None or "No sources available"
    if sources and sources != "No sources available":
        formatted_output += f"\nsource : {sources}\n"

    # Append explore next
    formatted_output += f"\n{explore_next}"

    return formatted_output.strip()




def query_oracle(text: str):
    """Invokes the LangGraph agent and extracts a cleaned response."""
    response = runnable.invoke({
        "input": text,
        "chat_history": []
    })
    # return extract_final_answer(response)
    return extract_and_format_final_answer(response)
        
    
    # except Exception as e:
    #     return f"Error: {str(e)}"

# Set up Gradio interface
interface = gr.Interface(
    fn=query_oracle,
    inputs=gr.Textbox(label="Enter your query"),
    outputs=gr.Textbox(label="Response"),
    title="LangGraph Assistant",
    description="Ask a question and get a structured response with sources and next steps."
)

# Launch Gradio app
interface.launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7863
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7863/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
